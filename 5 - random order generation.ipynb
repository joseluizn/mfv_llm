# %%
import random

import openai
import numpy as np
import pandas as pd
from getpass import getpass

from helpers import run_random_order

openai.api_key = getpass()

# %%
def cohen_d(x,y):
        from math import sqrt
        try:
            d = (np.mean(x) - np.mean(y)) / sqrt((np.std(x, ddof=1) ** 2 + np.std(y, ddof=1) ** 2) / 2.0)
            return d
        except ZeroDivisionError:
            return np.nan


def compare_randomized(df_ordered, df_randomized):
    import scipy.stats
    from scipy.stats import mannwhitneyu
    from statsmodels.stats.multitest import multipletests
    test_results = list()

    for code in df_ordered.columns:
        ordered_answers = df_ordered[code]

        randomized_answer = df_randomized[code]
        if df_randomized[str(code)].nunique() < 3 or df_ordered[str(code)].nunique() < 3:
            print(
                f"Code: {code} had {df_ordered[str(code)].nunique()} different answers when generated in order"
            )
            print(
                f"Code: {code} had {df_randomized[str(code)].nunique()} different answers when generated randomized"
            )

        test_results.append(
            (
                code,
                np.median(ordered_answers),
                scipy.stats.median_abs_deviation(ordered_answers),
                np.median(randomized_answer),
                scipy.stats.median_abs_deviation(randomized_answer),
                cohen_d(ordered_answers, randomized_answer),
                *mannwhitneyu(ordered_answers, randomized_answer),
            )
        )

    df_tests = pd.DataFrame(
        test_results,
        columns=["mfv_code", "mediana_ordered", "MAD_ordered", "mediana_randomized", "MAD_randomized", "cohen_d", "u", "p-value"],
    )
    df_tests["rejected"], df_tests["adjusted_p-value"], _, _ = multipletests(
        df_tests["p-value"],
        alpha=0.05,
        method="bonferroni"
    )
    # round adjusted p-value to 3 decimals
    df_tests["adjusted_p-value"] = df_tests["adjusted_p-value"].apply(lambda x: round(x, 4))

    df_tests["median_dif"] = df_tests["mediana_ordered"] - df_tests["mediana_randomized"]
    return df_tests

# %%
# df = run_random_order(128, "gpt-3.5-turbo")

# df.head(2)

# %%
df_randomized_order = pd.read_csv("data/random_order/results_gpt-3.5-turbo_2023-08-30_12-45.csv")

# %%
df_ordered = pd.read_csv("data/results_original_gpt-3.5-turbo_2023-08-13_22-43.csv")

df_ordered.head(2)
# Out:
#    102  103  104  105  108  109  110  111  112  113  ...  714  715  716  801  \
# 0    4    4    3    4    4    3    4    3    4    3  ...    5    4    5    5
# 1    4    3    3    4    4    2    2    3    4    2  ...    5    4    5    5
#
#    802  803  804  805  808  810
# 0    3    5    4    3    3    3
# 1    4    5    5    4    4    4
#
# [2 rows x 68 columns]

# %%
df_comparison = compare_randomized(df_ordered, df_randomized_order)

df_comparison
# Out:
# Code: 201 had 2 different answers when generated in order
# Code: 201 had 3 different answers when generated randomized
# Code: 202 had 2 different answers when generated in order
# Code: 202 had 2 different answers when generated randomized
# Code: 203 had 2 different answers when generated in order
# Code: 203 had 3 different answers when generated randomized
# Code: 208 had 4 different answers when generated in order
# Code: 208 had 2 different answers when generated randomized
# Code: 406 had 2 different answers when generated in order
# Code: 406 had 4 different answers when generated randomized
# Code: 410 had 2 different answers when generated in order
# Code: 410 had 4 different answers when generated randomized
# Code: 804 had 2 different answers when generated in order
# Code: 804 had 3 different answers when generated randomized
#    mfv_code  mediana_ordered  MAD_ordered  mediana_randomized  MAD_randomized  \
# 0       102              4.0          0.0                 3.0             0.0
# 1       103              3.0          0.0                 4.0             1.0
# 2       104              3.0          0.0                 3.0             1.0
# 3       105              4.0          0.0                 4.0             1.0
# 4       108              4.0          0.0                 4.0             0.0
# ..      ...              ...          ...                 ...             ...
# 63      803              5.0          0.0                 5.0             0.0
# 64      804              5.0          0.0                 5.0             0.0
# 65      805              4.0          1.0                 4.0             1.0
# 66      808              4.0          1.0                 5.0             0.0
# 67      810              4.0          1.0                 4.0             1.0
#
#      cohen_d        u       p-value  rejected  adjusted_p-value  median_dif
# 0   1.725088  13871.5  8.453435e-27      True            0.0000         1.0
# 1  -0.193066   6707.0  1.531834e-02     False            1.0000        -1.0
# 2  -0.225565   7088.0  8.163854e-02     False            1.0000         0.0
# 3   0.280471   8994.0  6.026773e-02     False            1.0000         0.0
# 4   0.900326  11350.5  2.502544e-10      True            0.0000         0.0
# ..       ...      ...           ...       ...               ...         ...
# 63 -0.071815   7500.5  5.378434e-02     False            1.0000         0.0
# 64 -0.354680   6741.0  3.891344e-05      True            0.0026         0.0
# 65  0.841311  11219.5  5.077599e-09      True            0.0000         0.0
# 66 -0.979403   4371.5  1.409224e-13      True            0.0000        -1.0
# 67 -0.125365   7410.5  2.866498e-01     False            1.0000         0.0
#
# [68 rows x 11 columns]

# %%
df_comparison["rejected"].value_counts()
# Out:
# True     44
# False    24
# Name: rejected, dtype: int64

# %%
df_comparison.query("rejected == True").median_dif.value_counts()
# Out:
#  0.0    15
#  1.0    14
# -1.0    12
#  2.0     3
# Name: median_dif, dtype: int64

# %%
df_comparison.query("rejected == True and median_dif != 0")
# Out:
#    mfv_code  mediana_ordered  MAD_ordered  mediana_randomized  MAD_randomized  \
# 0       102              4.0          0.0                 3.0             0.0
# 6       110              4.0          0.0                 3.0             0.0
# 7       111              3.0          0.0                 4.0             0.0
# 8       112              4.0          0.0                 3.0             1.0
# 13      203              5.0          0.0                 4.0             0.0
# 16      206              4.0          0.0                 5.0             0.0
# 18      208              4.0          0.0                 5.0             0.0
# 19      303              3.0          0.0                 4.0             0.0
# 20      402              3.0          0.0                 4.0             0.0
# 21      403              3.0          0.0                 4.0             0.0
# 22      404              4.0          0.0                 3.0             0.0
# 25      408              3.0          0.0                 4.0             0.0
# 26      409              4.0          0.0                 3.0             0.0
# 27      410              5.0          0.0                 3.0             0.0
# 29      501              3.0          0.0                 4.0             1.0
# 30      502              4.0          0.5                 3.0             1.0
# 35      510              4.0          0.0                 3.0             0.0
# 38      603              4.0          0.0                 2.0             1.0
# 40      605              3.0          0.0                 4.0             0.0
# 46      701              4.0          0.0                 3.0             0.0
# 47      702              3.0          0.0                 2.0             1.0
# 48      703              3.0          0.0                 4.0             1.0
# 51      706              4.0          1.0                 3.0             1.0
# 53      709              4.0          1.0                 3.0             1.0
# 55      711              4.0          0.0                 3.0             1.0
# 58      714              4.0          0.0                 3.0             0.0
# 60      716              5.0          0.0                 3.0             1.0
# 62      802              4.0          0.0                 5.0             0.0
# 66      808              4.0          1.0                 5.0             0.0
#
#      cohen_d        u       p-value  rejected  adjusted_p-value  median_dif
# 0   1.725088  13871.5  8.453435e-27      True            0.0000         1.0
# 6   1.527721  13585.0  7.186227e-24      True            0.0000         1.0
# 7  -1.374316   2979.5  4.552575e-21      True            0.0000        -1.0
# 8   0.593578  10399.0  8.306681e-06      True            0.0006         1.0
# 13  1.980468  13941.0  1.690821e-32      True            0.0000         1.0
# 16 -1.427317   3027.0  1.198153e-20      True            0.0000        -1.0
# 18 -3.268208    350.5  1.865839e-46      True            0.0000        -1.0
# 19 -1.373619   2822.0  1.208141e-21      True            0.0000        -1.0
# 20 -1.957039   1667.5  3.750885e-31      True            0.0000        -1.0
# 21 -1.070717   3981.0  1.097246e-14      True            0.0000        -1.0
# 22  0.571615  10206.5  2.457772e-05      True            0.0017         1.0
# 25 -1.131976   3733.5  3.806602e-16      True            0.0000        -1.0
# 26  1.650052  13708.5  6.232997e-26      True            0.0000         1.0
# 27  3.464209  15780.0  4.763704e-47      True            0.0000         2.0
# 29 -0.626008   5383.0  4.931246e-07      True            0.0000        -1.0
# 30  2.017042  14571.0  2.348921e-32      True            0.0000         1.0
# 35  1.526700  13678.5  7.088903e-25      True            0.0000         1.0
# 38  1.867798  14009.0  4.400817e-28      True            0.0000         2.0
# 40 -2.186390   1443.5  6.805606e-34      True            0.0000        -1.0
# 46  1.008013  12026.0  2.226948e-13      True            0.0000         1.0
# 47  1.001961  11937.5  2.415178e-13      True            0.0000         1.0
# 48 -0.404852   5757.0  4.898532e-05      True            0.0033        -1.0
# 51  0.496415   9821.0  6.765240e-04      True            0.0460         1.0
# 53  0.557226  10416.0  9.205038e-06      True            0.0006         1.0
# 55  1.303250  12824.0  1.124087e-18      True            0.0000         1.0
# 58  1.503165  13594.5  4.006227e-24      True            0.0000         1.0
# 60  2.261613  14829.5  1.017131e-33      True            0.0000         2.0
# 62 -1.723100   1717.0  2.392525e-31      True            0.0000        -1.0
# 66 -0.979403   4371.5  1.409224e-13      True            0.0000        -1.0

# %% [markdown]
# # GPT-4

# %%
# openai.organization = "org-bduO767V60bsXkNHgnzwStjp"
# df = run_random_order(128, "gpt-4")

# %% [markdown]
# ## Comparison

# %%
df = pd.read_csv("data/random_order/results_gpt-4_2023-09-05_19-40.csv")
df.head(2)
# Out:
#    102  103  104  105  108  109  110  111  112  113  ...  714  715  716  801  \
# 0    3    4    3    4    4    4    3    4    4    3  ...    3    4    3    5
# 1    4    4    4    5    5    5    4    5    5    3  ...    2    4    2    5
#
#    802  803  804  805  808  810
# 0    5    5    5    2    5    4
# 1    4    5    5    3    4    3
#
# [2 rows x 68 columns]

# %%
df_ordered_gpt4 = pd.concat(
    map(pd.read_csv, Path("data").glob("results_original_gpt-4*.csv"))
)

df_ordered_gpt4.head(2)
# Out:
#    102  103  104  105  108  109  110  111  112  113  ...  714  715  716  801  \
# 0    4    4    4    5    5    3    5    4    5    3  ...    2    2    4    5
# 1    4    4    4    5    5    3    5    3    5    4  ...    5    3    4    5
#
#    802  803  804  805  808  810
# 0    4    5    5    4    4    4
# 1    5    5    5    4    5    5
#
# [2 rows x 68 columns]

# %%
comparison_gpt4 = compare_randomized(df_ordered_gpt4, df)

comparison_gpt4["rejected"].value_counts()
# Out:
# Code: 102 had 2 different answers when generated in order
# Code: 102 had 3 different answers when generated randomized
# Code: 105 had 2 different answers when generated in order
# Code: 105 had 4 different answers when generated randomized
# Code: 108 had 1 different answers when generated in order
# Code: 108 had 4 different answers when generated randomized
# Code: 110 had 2 different answers when generated in order
# Code: 110 had 4 different answers when generated randomized
# Code: 112 had 2 different answers when generated in order
# Code: 112 had 4 different answers when generated randomized
# Code: 201 had 1 different answers when generated in order
# Code: 201 had 1 different answers when generated randomized
# Code: 202 had 2 different answers when generated in order
# Code: 202 had 2 different answers when generated randomized
# Code: 203 had 1 different answers when generated in order
# Code: 203 had 3 different answers when generated randomized
# Code: 204 had 2 different answers when generated in order
# Code: 204 had 2 different answers when generated randomized
# Code: 205 had 2 different answers when generated in order
# Code: 205 had 2 different answers when generated randomized
# Code: 206 had 2 different answers when generated in order
# Code: 206 had 2 different answers when generated randomized
# Code: 207 had 1 different answers when generated in order
# Code: 207 had 1 different answers when generated randomized
# Code: 208 had 3 different answers when generated in order
# Code: 208 had 1 different answers when generated randomized
# Code: 303 had 2 different answers when generated in order
# Code: 303 had 3 different answers when generated randomized
# Code: 402 had 3 different answers when generated in order
# Code: 402 had 2 different answers when generated randomized
# Code: 403 had 2 different answers when generated in order
# Code: 403 had 3 different answers when generated randomized
# Code: 404 had 2 different answers when generated in order
# Code: 404 had 4 different answers when generated randomized
# Code: 405 had 2 different answers when generated in order
# Code: 405 had 2 different answers when generated randomized
# Code: 406 had 3 different answers when generated in order
# Code: 406 had 2 different answers when generated randomized
# Code: 408 had 4 different answers when generated in order
# Code: 408 had 2 different answers when generated randomized
# Code: 410 had 1 different answers when generated in order
# Code: 410 had 3 different answers when generated randomized
# Code: 411 had 2 different answers when generated in order
# Code: 411 had 2 different answers when generated randomized
# Code: 502 had 2 different answers when generated in order
# Code: 502 had 3 different answers when generated randomized
# Code: 801 had 1 different answers when generated in order
# Code: 801 had 4 different answers when generated randomized
# Code: 803 had 1 different answers when generated in order
# Code: 803 had 2 different answers when generated randomized
# Code: 804 had 2 different answers when generated in order
# Code: 804 had 1 different answers when generated randomized
# Code: 808 had 2 different answers when generated in order
# Code: 808 had 4 different answers when generated randomized
# True     47
# False    21
# Name: rejected, dtype: int64

# %%
df_comparison.query("rejected == True").median_dif.value_counts()
# Out:
#  0.0    15
#  1.0    14
# -1.0    12
#  2.0     3
# Name: median_dif, dtype: int64

# %%
df_comparison.query("rejected == True and median_dif != 0")
# Out:
#    mfv_code  mediana_ordered  MAD_ordered  mediana_randomized  MAD_randomized  \
# 0       102              4.0          0.0                 3.0             0.0
# 6       110              4.0          0.0                 3.0             0.0
# 7       111              3.0          0.0                 4.0             0.0
# 8       112              4.0          0.0                 3.0             1.0
# 13      203              5.0          0.0                 4.0             0.0
# 16      206              4.0          0.0                 5.0             0.0
